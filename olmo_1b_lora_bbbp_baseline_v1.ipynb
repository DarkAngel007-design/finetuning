# %%
# !git clone https://github.com/DarkAngel007-design/finetuning.git

# %%
cd finetuning
# Out:
# /kaggle/working/finetuning

# %%
# !grep -n "load_in_8bit" train_olmo_bbbp.py

# %%
# !sed -n '1,200p' train_olmo_bbbp.py

# %%
# !grep -n "AutoModelForCausalLM" train_olmo_bbbp.py

# %%
# !grep -n "use_cache" train_olmo_bbbp.py

# %%
# !pip install git+https://github.com/allenai/OLMo.git

# %%
# !pip install "numpy<2"

# !pip install \
  torch==2.2.2 \
  torchvision==0.17.2 \
  transformers==4.45.2 \
  peft==0.11.1 \
  accelerate \
  datasets \
  deepchem \
  scikit-learn

# !pip install git+https://github.com/allenai/OLMo.git

# %%
# !pip uninstall -y numpy pandas pyarrow datasets
# !pip install --no-cache-dir numpy==1.26.4
# !pip install --no-cache-dir pandas==2.1.4
# !pip install --no-cache-dir pyarrow==14.0.2 datasets==2.18.0

# %%
# !pip install --no-cache-dir \
  torch==2.2.2 \
  torchvision==0.17.2 \
  transformers==4.45.2 \
  peft==0.11.1 \
  accelerate \
  deepchem \
  scikit-learn

# %%
# !pip install --no-cache-dir git+https://github.com/allenai/OLMo.git

# %%
import numpy as np
import pandas as pd
import torch
import transformers
import peft
import hf_olmo

print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("torch:", torch.__version__)
print("transformers:", transformers.__version__)
print("peft:", peft.__version__)
print("hf_olmo OK")

# %%
# !pip install -U bitsandbytes

# %%
pip install -U numpy pandas pyarrow datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 87.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 95.1 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 42.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 37.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: datasets
# ...

# %%
# !pip install \
  transformers==4.45.2 \
  peft==0.11.1 \
  accelerate \
  deepchem \
  scikit-learn \
  git+https://github.com/allenai/OLMo.git
# Out:
# ...
#   Cloning https://github.com/allenai/OLMo.git to /tmp/pip-req-build-1ubauez_
#   Running command git clone --filter=blob:none --quiet https://github.com/allenai/OLMo.git /tmp/pip-req-build-1ubauez_
#   Resolved https://github.com/allenai/OLMo.git to commit 090253dac6688f2532509daa7aa2eb5fae50e956
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.1
#     Uninstalling numpy-2.4.1:
#       Successfully uninstalled numpy-2.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import numpy as np
import torch
import transformers
import peft
import hf_olmo

print("numpy:", np.__version__)
print("torch:", torch.__version__)
print("hf_olmo OK")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# numpy: 1.26.4
# torch: 2.10.0+cu128
# hf_olmo OK

# %%
# !python prepare_bbbp.py
# Out:
# Saved BBBP instruction CSVs

# %%
# !python train_olmo_bbbp.py
# Out:
# 2026-01-28 13:18:30.686900: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769606310.710461    2734 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769606310.718065    2734 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769606310.737895    2734 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.11 KiB | 1.11 MiB/s, done.
# From https://github.com/DarkAngel007-design/finetuning
#  * branch            main       -> FETCH_HEAD
#    f3dac77..a637689  main       -> origin/main
# Updating f3dac77..a637689
# Fast-forward
#  eval_roc_auc.py | 10 +++++++---
#  1 file changed, 7 insertions(+), 3 deletions(-)

# %%
# !python eval_roc_auc.py
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# 100%|█████████████████████████████████████████| 205/205 [00:06<00:00, 30.45it/s]
# ROC-AUC: 0.6689
